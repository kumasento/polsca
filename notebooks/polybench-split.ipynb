# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Polybench Statement Splitting Study

# %% [markdown]
# ## Setup
#
# We need to put the `python/` directory into the `PYTHONPATH`.

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.dirname(os.path.realpath(os.getcwd())))

# %%
import python.utils.polybench as pb_utils

# %%
pb_utils.discover_examples('./example/polybench')
# Out:
# ['./example/polybench/datamining/correlation',
#  './example/polybench/datamining/covariance',
#  './example/polybench/linear-algebra/blas/gemm',
#  './example/polybench/linear-algebra/blas/gemver',
#  './example/polybench/linear-algebra/blas/gesummv',
#  './example/polybench/linear-algebra/blas/symm',
#  './example/polybench/linear-algebra/blas/syr2k',
#  './example/polybench/linear-algebra/blas/syrk',
#  './example/polybench/linear-algebra/blas/trmm',
#  './example/polybench/linear-algebra/kernels/2mm',
#  './example/polybench/linear-algebra/kernels/3mm',
#  './example/polybench/linear-algebra/kernels/atax',
#  './example/polybench/linear-algebra/kernels/bicg',
#  './example/polybench/linear-algebra/kernels/doitgen',
#  './example/polybench/linear-algebra/kernels/mvt',
#  './example/polybench/linear-algebra/solvers/cholesky',
#  './example/polybench/linear-algebra/solvers/durbin',
#  './example/polybench/linear-algebra/solvers/gramschmidt',
#  './example/polybench/linear-algebra/solvers/lu',
#  './example/polybench/linear-algebra/solvers/ludcmp',
#  './example/polybench/linear-algebra/solvers/trisolv',
#  './example/polybench/medley/deriche',
#  './example/polybench/medley/floyd-warshall',
#  './example/polybench/medley/nussinov',
#  './example/polybench/stencils/adi',
#  './example/polybench/stencils/fdtd-2d',
#  './example/polybench/stencils/heat-3d',
#  './example/polybench/stencils/jacobi-1d',
#  './example/polybench/stencils/jacobi-2d',
#  './example/polybench/stencils/seidel-2d']

# %% [markdown]
# ## Run `pb-flow`

# %%
pb_utils.pb_flow_process('./tmp/phism/pb-flow.20210830-164305/stencils/jacobi-1d', './tmp/phism/pb-flow.20210830-164305/', pb_utils.PbFlowOptions(
  pb_dir=os.path.join(pb_utils.get_project_root(), 'example', 'polybench'),
  job=1,
  polymer=True,
  split="SPLIT",
  cosim=True,
  debug=True,
  dataset='MINI',
  cleanup=False,
))
# Out:
# >>> Finished jacobi-1d       elapsed: 245.606856 secs   Status: 0  Error: "No Error"

# %%
pb_utils.pb_flow_process('./tmp/phism/pb-flow.20210830-164305/datamining/covariance', './tmp/phism/pb-flow.20210830-164305/', pb_utils.PbFlowOptions(
  pb_dir=os.path.join(pb_utils.get_project_root(), 'example', 'polybench'),
  job=1,
  polymer=True,
  split="HEURISTIC",
  cosim=True,
  debug=True,
  dataset='MINI',
  cleanup=False,
))
# Out:
# >>> Finished covariance      elapsed: 276.289361 secs   Status: 0  Error: "No Error"

# %%
pb_utils.pb_flow_runner(pb_utils.PbFlowOptions(**{
  'pb_dir': os.path.join(pb_utils.get_project_root(), 'example', 'polybench'),
  'job': 30,
  'polymer': True,
  'split': 'HEURISTIC',
  'cosim': True,
  'debug': True,
  'dataset': 'MINI',
  'cleanup': False
}))
# Out:
# >>> Starting 30 jobs (work_dir=/mnt/ccnas2/bdp/rz3515/projects/phism/tmp/phism/pb-flow.20210831-121000) ...
# >>> Finished nussinov        elapsed: 130.008148 secs   Status: 0  Error: "No Error"
# >>> Finished floyd-warshall  elapsed: 130.213632 secs   Status: 0  Error: "No Error"
# >>> Finished atax            elapsed: 209.677329 secs   Status: 1  Error: "Cosim failed."
# >>> Finished trmm            elapsed: 212.190904 secs   Status: 1  Error: "Cosim failed."
# >>> Finished gemver          elapsed: 221.197148 secs   Status: 1  Error: "Cosim failed."
# >>> Finished jacobi-1d       elapsed: 232.047331 secs   Status: 0  Error: "No Error"
# >>> Finished syrk            elapsed: 233.845062 secs   Status: 1  Error: "Cosim failed."
# >>> Finished mvt             elapsed: 238.163384 secs   Status: 0  Error: "No Error"
# >>> Finished syr2k           elapsed: 242.304350 secs   Status: 1  Error: "Cosim failed."
# >>> Finished bicg            elapsed: 243.523128 secs   Status: 0  Error: "No Error"
# >>> Finished gesummv         elapsed: 244.198902 secs   Status: 0  Error: "No Error"
# >>> Finished gemm            elapsed: 251.540971 secs   Status: 1  Error: "Cosim failed."
# >>> Finished doitgen         elapsed: 253.202872 secs   Status: 0  Error: "No Error"
# >>> Finished trisolv         elapsed: 254.553732 secs   Status: 0  Error: "No Error"
# >>> Finished durbin          elapsed: 260.603912 secs   Status: 0  Error: "No Error"
# >>> Finished symm            elapsed: 270.532537 secs   Status: 0  Error: "No Error"
# >>> Finished heat-3d         elapsed: 272.592058 secs   Status: 1  Error: "Phism syn failed."
# >>> Finished correlation     elapsed: 285.818325 secs   Status: 1  Error: "Cosim failed."
# >>> Finished deriche         elapsed: 306.731072 secs   Status: 1  Error: "Phism syn failed."
# >>> Finished covariance      elapsed: 315.425007 secs   Status: 0  Error: "No Error"
# >>> Finished 2mm             elapsed: 317.778692 secs   Status: 0  Error: "No Error"
# >>> Finished gramschmidt     elapsed: 331.677477 secs   Status: 1  Error: "Cosim failed."
# >>> Finished 3mm             elapsed: 360.642435 secs   Status: 0  Error: "No Error"
# >>> Finished cholesky        elapsed: 369.102245 secs   Status: 0  Error: "No Error"
# >>> Finished ludcmp          elapsed: 410.467383 secs   Status: 0  Error: "No Error"
# >>> Finished lu              elapsed: 476.918664 secs   Status: 0  Error: "No Error"
# >>> Finished fdtd-2d         elapsed: 562.028866 secs   Status: 1  Error: "Cosim failed."
# >>> Finished jacobi-2d       elapsed: 629.772615 secs   Status: 0  Error: "No Error"
# >>> Finished adi             elapsed: 1418.969087 secs   Status: 0  Error: "No Error"
# >>> Finished seidel-2d       elapsed: 1513.144791 secs   Status: 0  Error: "No Error"
# Elapsed time: 1513.392079 sec

# %% [markdown]
# ## Results
#
# Here we list all the results as a table.

# %%
baseline = pb_utils.to_pandas(pb_utils.process_pb_flow_result_dir(os.path.join(os.getcwd(), 'tmp', 'phism', 'pb-flow.20210526-220244')))
baseline
# Out:
#               name   phism_synth tbgen_cosim   phism_cosim  latency DSP_usage  \
# 0              2mm       SUCCESS     SUCCESS       SUCCESS   108895        54
# 1              3mm       SUCCESS     SUCCESS       SUCCESS   173643        84
# 2              adi       SUCCESS     SUCCESS  COSIM_FAILED     None        47
# 3             atax       SUCCESS     SUCCESS  COSIM_FAILED     None        20
# 4             bicg       SUCCESS     SUCCESS       SUCCESS    23798        20
# 5         cholesky       SUCCESS     SUCCESS       SUCCESS   124925        20
# 6      correlation       SUCCESS     SUCCESS  COSIM_FAILED     None        29
# 7       covariance       SUCCESS     SUCCESS       SUCCESS   134618        42
# 8          deriche  CANNOT_SYNTH     SUCCESS        NO_LOG   237664      None
# 9          doitgen       SUCCESS     SUCCESS       SUCCESS    96242        16
# 10          durbin       SUCCESS     SUCCESS       SUCCESS     9847        14
# 11         fdtd-2d       SUCCESS     SUCCESS  COSIM_FAILED     None        27
# 12  floyd-warshall       SUCCESS     SUCCESS       SUCCESS   434885         5
# 13            gemm       SUCCESS     SUCCESS  COSIM_FAILED     None        34
# 14          gemver       SUCCESS     SUCCESS  COSIM_FAILED     None        18
# 15         gesummv       SUCCESS     SUCCESS       SUCCESS     6289        16
# 16     gramschmidt       SUCCESS     SUCCESS  COSIM_FAILED     None        22
# 17         heat-3d       SUCCESS     SUCCESS  COSIM_FAILED     None       135
# 18       jacobi-1d       SUCCESS     SUCCESS       SUCCESS    19800        14
# 19       jacobi-2d       SUCCESS     SUCCESS       SUCCESS  1106347        25
# 20              lu       SUCCESS     SUCCESS       SUCCESS   209626        29
# 21          ludcmp       SUCCESS     SUCCESS       SUCCESS   180811        16
# 22             mvt       SUCCESS     SUCCESS       SUCCESS    10737        16
# 23        nussinov       SUCCESS     SUCCESS       SUCCESS    92262         5
# 24       seidel-2d       SUCCESS     SUCCESS       SUCCESS  2559789         5
# 25            symm       SUCCESS     SUCCESS       SUCCESS    71922        39
# 26           syr2k       SUCCESS     SUCCESS  COSIM_FAILED     None        21
# 27            syrk       SUCCESS     SUCCESS  COSIM_FAILED     None        21
# 28         trisolv       SUCCESS     SUCCESS       SUCCESS     8197        15
# 29            trmm       SUCCESS     SUCCESS       SUCCESS    50147        22
#
#    FF_usage LUT_usage BRAM_18K_usage URAM_usage DSP_avail FF_avail LUT_avail  \
# 0     17995     16711              0          0       220   106400     53200
# 1     24775     25744              0          0       220   106400     53200
# 2     10752     13021              0          0       220   106400     53200
# 3      5870      6664              0          0       220   106400     53200
# 4      5896      6660              0          0       220   106400     53200
# 5      5832      7985              0          0       220   106400     53200
# 6     14751     16201              0          0       220   106400     53200
# 7     15810     16816              0          0       220   106400     53200
# 8      None      None           None       None      None     None      None
# 9      3874      4697              0          0       220   106400     53200
# 10     2807      3165              2          0       220   106400     53200
# 11    68166     71276              0          0       220   106400     53200
# 12     2898      2856              0          0       220   106400     53200
# 13     8249      8105              0          0       220   106400     53200
# 14     6068      5960              0          0       220   106400     53200
# 15     3791      4041              0          0       220   106400     53200
# 16     7160      7741              0          0       220   106400     53200
# 17   105115    106030              0          0       220   106400     53200
# 18     8250     12755              0          0       220   106400     53200
# 19    42039     48485              0          0       220   106400     53200
# 20    13138     14273              0          0       220   106400     53200
# 21     3725      4923              0          0       220   106400     53200
# 22     3142      3377              0          0       220   106400     53200
# 23     5310      7641              0          0       220   106400     53200
# 24     7708     10203              0          0       220   106400     53200
# 25     4437      5760              0          0       220   106400     53200
# 26     6166      5919              0          0       220   106400     53200
# 27     5844      5885              0          0       220   106400     53200
# 28     3036      3921              0          0       220   106400     53200
# 29     6976      7571              0          0       220   106400     53200
#
#    BRAM_18K_avail URAM_avail
# 0             280          0
# 1             280          0
# 2             280          0
# 3             280          0
# 4             280          0
# 5             280          0
# 6             280          0
# 7             280          0
# 8            None       None
# 9             280          0
# 10            280          0
# 11            280          0
# 12            280          0
# 13            280          0
# 14            280          0
# 15            280          0
# 16            280          0
# 17            280          0
# 18            280          0
# 19            280          0
# 20            280          0
# 21            280          0
# 22            280          0
# 23            280          0
# 24            280          0
# 25            280          0
# 26            280          0
# 27            280          0
# 28            280          0
# 29            280          0

# %%
polymer = pb_utils.to_pandas(pb_utils.process_pb_flow_result_dir(os.path.join(os.getcwd(), 'tmp', 'phism', 'pb-flow.20210831-121000')))
polymer
# Out:
#               name   phism_synth tbgen_cosim   phism_cosim  latency DSP_usage  \
# 0              2mm       SUCCESS     SUCCESS       SUCCESS   109556        38
# 1              3mm       SUCCESS     SUCCESS       SUCCESS   175891        55
# 2              adi       SUCCESS     SUCCESS       SUCCESS   769993        43
# 3             atax       SUCCESS     SUCCESS  COSIM_FAILED     None        20
# 4             bicg       SUCCESS     SUCCESS       SUCCESS    23798        20
# 5         cholesky       SUCCESS     SUCCESS       SUCCESS   124925        20
# 6      correlation       SUCCESS     SUCCESS  COSIM_FAILED     None        29
# 7       covariance       SUCCESS     SUCCESS       SUCCESS   134848        32
# 8          deriche  CANNOT_SYNTH     SUCCESS        NO_LOG   237664      None
# 9          doitgen       SUCCESS     SUCCESS       SUCCESS    96242        16
# 10          durbin       SUCCESS     SUCCESS       SUCCESS     9847        14
# 11         fdtd-2d       SUCCESS     SUCCESS  COSIM_FAILED     None        27
# 12  floyd-warshall       SUCCESS     SUCCESS       SUCCESS   434885         5
# 13            gemm       SUCCESS     SUCCESS  COSIM_FAILED     None        34
# 14          gemver       SUCCESS     SUCCESS  COSIM_FAILED     None        18
# 15         gesummv       SUCCESS     SUCCESS       SUCCESS    12092        18
# 16     gramschmidt       SUCCESS     SUCCESS  COSIM_FAILED     None        22
# 17         heat-3d       SUCCESS     SUCCESS        NO_LOG   213181      None
# 18       jacobi-1d       SUCCESS     SUCCESS       SUCCESS    19800        14
# 19       jacobi-2d       SUCCESS     SUCCESS       SUCCESS  1106347        25
# 20              lu       SUCCESS     SUCCESS       SUCCESS   209626        29
# 21          ludcmp       SUCCESS     SUCCESS       SUCCESS   180811        16
# 22             mvt       SUCCESS     SUCCESS       SUCCESS    10737        16
# 23        nussinov       SUCCESS     SUCCESS       SUCCESS    92262         5
# 24       seidel-2d       SUCCESS     SUCCESS       SUCCESS  2559789         5
# 25            symm       SUCCESS     SUCCESS       SUCCESS    71922        39
# 26           syr2k       SUCCESS     SUCCESS  COSIM_FAILED     None        21
# 27            syrk       SUCCESS     SUCCESS  COSIM_FAILED     None        21
# 28         trisolv       SUCCESS     SUCCESS       SUCCESS     8197        15
# 29            trmm       SUCCESS     SUCCESS  COSIM_FAILED     None        20
#
#    FF_usage LUT_usage BRAM_18K_usage URAM_usage DSP_avail FF_avail LUT_avail  \
# 0     14541     13845              0          0       220   106400     53200
# 1     17921     19684              2          0       220   106400     53200
# 2      8449     10162              0          0       220   106400     53200
# 3      5870      6664              0          0       220   106400     53200
# 4      5896      6660              0          0       220   106400     53200
# 5      5832      7985              0          0       220   106400     53200
# 6     13986     15283              0          0       220   106400     53200
# 7     12788     14027              0          0       220   106400     53200
# 8      None      None           None       None      None     None      None
# 9      3874      4697              0          0       220   106400     53200
# 10     2807      3165              2          0       220   106400     53200
# 11    68166     71276              0          0       220   106400     53200
# 12     2898      2856              0          0       220   106400     53200
# 13     8249      8105              0          0       220   106400     53200
# 14     6068      5960              0          0       220   106400     53200
# 15     5337      5678              0          0       220   106400     53200
# 16     7160      7741              0          0       220   106400     53200
# 17     None      None           None       None      None     None      None
# 18     8250     12755              0          0       220   106400     53200
# 19    42039     48485              0          0       220   106400     53200
# 20    13138     14273              0          0       220   106400     53200
# 21     3725      4923              0          0       220   106400     53200
# 22     3142      3377              0          0       220   106400     53200
# 23     5310      7641              0          0       220   106400     53200
# 24     7708     10203              0          0       220   106400     53200
# 25     4437      5760              0          0       220   106400     53200
# 26     6166      5919              0          0       220   106400     53200
# 27     5844      5885              0          0       220   106400     53200
# 28     3036      3921              0          0       220   106400     53200
# 29     6257      6679              0          0       220   106400     53200
#
#    BRAM_18K_avail URAM_avail
# 0             280          0
# 1             280          0
# 2             280          0
# 3             280          0
# 4             280          0
# 5             280          0
# 6             280          0
# 7             280          0
# 8            None       None
# 9             280          0
# 10            280          0
# 11            280          0
# 12            280          0
# 13            280          0
# 14            280          0
# 15            280          0
# 16            280          0
# 17           None       None
# 18            280          0
# 19            280          0
# 20            280          0
# 21            280          0
# 22            280          0
# 23            280          0
# 24            280          0
# 25            280          0
# 26            280          0
# 27            280          0
# 28            280          0
# 29            280          0

# %%
base_succ = pb_utils.filter_success(baseline)
poly_succ = pb_utils.filter_success(polymer)

names = sorted(list(set(base_succ['name']) & set(poly_succ['name'])))

df = pd.DataFrame(columns=('name', 'base_lat', 'poly_lat'),
                  data=(zip(names,
                            base_succ[base_succ['name'].isin(names)]['latency'],
                            poly_succ[poly_succ['name'].isin(names)]['latency'])),
                  dtype=object)
df['speedup'] = (df['base_lat'] / df['poly_lat'])
df
# Out:
#               name base_lat poly_lat   speedup
# 0              2mm   108895   109556  0.993967
# 1              3mm   173643   175891  0.987219
# 2             bicg    23798    23798  1.000000
# 3         cholesky   124925   124925  1.000000
# 4       covariance   134618   134848  0.998294
# 5          doitgen    96242    96242  1.000000
# 6           durbin     9847     9847  1.000000
# 7   floyd-warshall   434885   434885  1.000000
# 8          gesummv     6289    12092  0.520096
# 9        jacobi-1d    19800    19800  1.000000
# 10       jacobi-2d  1106347  1106347  1.000000
# 11              lu   209626   209626  1.000000
# 12          ludcmp   180811   180811  1.000000
# 13             mvt    10737    10737  1.000000
# 14        nussinov    92262    92262  1.000000
# 15       seidel-2d  2559789  2559789  1.000000
# 16            symm    71922    71922  1.000000
# 17         trisolv     8197     8197  1.000000
